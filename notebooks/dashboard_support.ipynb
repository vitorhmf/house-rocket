# %%
import pandas as pd

# %%
df1 = pd.read_csv('../data/suggestion_list.csv')

# %%
df1.head()

pd.set_option('float_format', '{:.2f}'.format)

df1
# Out:
#      Unnamed: 0          id        date      price  bedrooms  bathrooms  \
# 0          1665  7322910030  2014-07-21 1095000.00         5       3.50
# 1          1787   525069099  2014-10-22  685000.00         3       2.50
# 2          3218  2723069129  2015-05-06  427000.00         3       2.50
# 3          3325   322069180  2014-11-20  649500.00         3       3.00
# 4          6674  7968460110  2014-06-19  280000.00         3       2.00
# ..          ...         ...         ...        ...       ...        ...
# 151       11202  2322029048  2014-11-19  999000.00         3       2.75
# 152       13360  4114601580  2014-07-24 1900000.00         6       4.00
# 153       15487  2624049091  2015-03-13 2903000.00         5       2.50
# 154       15908  1025039086  2014-09-16 1875000.00         3       2.50
# 155       19263  3126059023  2015-03-03 3395000.00         4       3.50
#
#      floors  waterfront  view  condition  ...  m2_above  m2_basement  \
# ...
